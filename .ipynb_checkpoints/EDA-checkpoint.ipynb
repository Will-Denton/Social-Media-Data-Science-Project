# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap

# %%
pew_2020 = pd.read_spss("data/NPORS-2024-Data-Release/NPORS 2020.sav")
pew_2021 = pd.read_spss("data/NPORS-2024-Data-Release/NPORS_2021_for_public_release.sav")
pew_2022 = pd.read_spss("data/NPORS-2024-Data-Release/NPORS_2022_for_public_release.sav")
pew_2023 = pd.read_spss("data/NPORS-2024-Data-Release/NPORS_2023_for_public_release.sav")
pew_2024 = pd.read_spss("data/NPORS-2024-Data-Release/NPORS_2024_for_public_release.sav")

filterAge = False
if (filterAge):
    pew_2021 = pew_2021[pew_2021["AGE_AP21"] != "Refused"]
    pew_2021["AGE_AP21"] = pd.to_numeric(pew_2021["AGE_AP21"])
    pew_2022 = pew_2022[pew_2022["AGE"] != "Refused"]
    pew_2022["AGE"] = pd.to_numeric(pew_2022["AGE"])
    pew_2020 = pew_2020[pew_2020["AGE_AP20"] < 30].reset_index(drop = True)
    pew_2021 = pew_2021[pew_2021["AGE_AP21"] < 30].reset_index(drop = True)
    pew_2022 = pew_2022[pew_2022["AGE"] < 30].reset_index(drop = True)
    pew_2023 = pew_2023[pew_2023["AGECAT"] == "18-29"].reset_index(drop = True)

# %%
pew_2020_sm = pew_2020[["SMUSE_a_AP20", "SMUSE_b_AP20", "SMUSE_c_AP20", "SMUSE_d_AP20", "SMUSE_e_AP20", "SMUSE_f_AP20", "SMUSE_g_AP20", "SMUSE_h_AP20"]].copy()
pew_2020_sm.columns = ["Facebook", "YouTube", "Twitter", "Instagram", "Snapchat", "WhatsApp", "LinkedIn", "Pinterest"]
pew_2021_sm = pew_2021[["SMUSE_a_AP21", "SMUSE_b_AP21", "SMUSE_c_AP21", "SMUSE_d_AP21", "SMUSE_e_AP21", "SMUSE_f_AP21", "SMUSE_g_AP21", "SMUSE_h_AP21"]].copy()
pew_2021_sm.columns = ["Facebook", "YouTube", "Twitter", "Instagram", "Snapchat", "WhatsApp", "LinkedIn", "Pinterest"]
pew_2022_sm = pew_2022[["SMUSE_a", "SMUSE_b", "SMUSE_c", "SMUSE_d", "SMUSE_e", "SMUSE_f", "SMUSE_g", "SMUSE_h", "SMUSE_i"]].copy()
pew_2022_sm.columns = ["Facebook", "YouTube", "Twitter", "Instagram", "Snapchat", "WhatsApp", "LinkedIn", "Pinterest", "TikTok"]
pew_2023_sm = pew_2023[["SMUSE_a", "SMUSE_b", "SMUSE_c", "SMUSE_d", "SMUSE_e", "SMUSE_f", "SMUSE_g", "SMUSE_h", "SMUSE_i", "SMUSE_j", "SMUSE_k"]].copy()
pew_2023_sm.columns = ["Facebook", "YouTube", "Twitter", "Instagram", "Snapchat", "WhatsApp", "LinkedIn", "Pinterest", "TikTok", "BeReal", "Reddit"]



datasets = [pew_2020_sm, pew_2021_sm, pew_2022_sm, pew_2023_sm]
social_media_list = ["Facebook", "YouTube", "Twitter", "Instagram", "Snapchat", "WhatsApp", "LinkedIn", "Pinterest", "TikTok", "BeReal", "Reddit"]

for sm in social_media_list:
    start_year = 2020
    year = start_year
    for dataset in datasets:
        if sm in dataset.columns:
            sm_counts = dataset.loc[:,sm].value_counts(normalize=True)
            proportion = sm_counts.get('Yes, use this', 0)  
            dataset.loc[:, sm + " Proportion "] = proportion
            #dataset.loc[:, "Year"] = year

        year += 1

pew_2020_sm = pew_2020_sm.drop(columns = social_media_list, errors = 'ignore').loc[1]
pew_2021_sm = pew_2021_sm.drop(columns = social_media_list, errors = 'ignore').loc[1]
pew_2022_sm = pew_2022_sm.drop(columns = social_media_list, errors = 'ignore').loc[1]
pew_2023_sm = pew_2023_sm.drop(columns = social_media_list, errors = 'ignore').loc[1]
            
pew_data = pd.DataFrame({"2020": pew_2020_sm, "2021": pew_2021_sm, "2022": pew_2022_sm, "2023": pew_2023_sm})
#display(pew_data)

pew_data = pew_data.reset_index()

pew_data.columns = ['Platform', "2020", "2021", "2022", "2023"]

pew_data_long = pd.melt(pew_data, id_vars='Platform', var_name='Year', value_name='Proportion')
#display(pew_data_long)

plt.figure(figsize=(10, 4.5))
sns.lineplot(data=pew_data_long, x='Year', y='Proportion', hue='Platform', marker='o')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OrdinalEncoder
import statsmodels.api as sm

def map_gender(value):
    if value == "Male":
        return "Male"
    elif value == "Female":
        return "Female"
    else:
        return "Other"

preds = [f"Q{i}" for i in [1, 2, 3, 4, 8]]
time_categories = [
    "Less than an Hour", 
    "Between 1 and 2 hours", 
    "Between 2 and 3 hours", 
    "Between 3 and 4 hours", 
    "Between 4 and 5 hours", 
    "More than 5 hours"
]

smmh = pd.read_csv("data/smmh.csv")
questions = smmh.columns
smmh.columns = ["time"] + [f"Q{i}" for i in range(1, 21)]

anx_questions = [f"Q{i}" for i in [13, 15, 18, 19, 20]]
smmh["anxiety_score"] = smmh[anx_questions].mean(axis = 1)
smmh["Q2"] = smmh["Q2"].apply(map_gender)
smmh['Q8'] = pd.Categorical(
    smmh['Q8'], 
    categories=time_categories, 
    ordered=True
)
ordinal_encoder = OrdinalEncoder(categories=[time_categories])
smmh['Q8'] = ordinal_encoder.fit_transform(smmh[['Q8']])

X = smmh[preds]
X = pd.get_dummies(X, columns = [f"Q{i}" for i in [2, 3, 4, 8]], drop_first = True)
X = X.apply(lambda col: col.astype(int) if col.dtype == bool else col)
X = sm.add_constant(X)
y = smmh["anxiety_score"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 216)

model = sm.OLS(y_train, X_train).fit()

# %%
from prettytable import PrettyTable

summ = pd.DataFrame(model.summary().tables[1]).iloc[:,[0, 1, 4]]
fig, ax = plt.subplots(figsize = (5, 4))

tbl = pd.plotting.table(ax, summ, loc = "center")
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
tbl.auto_set_column_width(col=list(range(len(summ.columns))))
tbl.scale(1.5, 1.5)  
tbl.auto_set_column_width([0, 1, 2])
tbl.get_celld()[(0, 0)].set_text_props(text='')
tbl.get_celld()[(0, 1)].set_text_props(text='') 

ax.grid(False)
ax.set_xticks([])
ax.set_yticks([]) 
ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.show()

# %%
smmh["Q8"].unique()
# Out:
# array([2., 5., 3., 0., 1., 4.])

# %%
plt.figure(figsize=(10, 4.5))
ax = sns.lineplot(data=pew_data_long, x='Year', y='Proportion', hue='Platform', marker='o')
plt.title("Proportion of respondents that use each platform")
ax.annotate('Figure 1: Line Graph of Social Media Platform Usage Proportions', xy = (0, -.2), xycoords='axes fraction')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
from scipy.stats import norm

y_pred = model.predict(X_train)
resids = y_train - y_pred
sd = np.std(resids, ddof = 1)
mean = 0
func_x = np.linspace(mean - (4 * sd), mean + (4 * sd), 1000)
pdf = norm.pdf(func_x, loc = mean, scale = sd)

plt.figure(figsize = (8,6))
ax = sns.histplot(resids)
plt.axvline(0, color = "black", linestyle = "--")
plt.xlabel("Residuals")
plt.ylabel("Count")
plt.title("Linear regression model residual density vs normal")
ax.annotate('Figure 4: Histogram of Residuals', xy = (0, -.15), xycoords='axes fraction')
plt.show()

# %%
from scipy.stats import norm

y_pred = model.predict(X_train)
resids = y_train - y_pred
sd = np.std(resids, ddof = 1)
mean = 0
func_x = np.linspace(mean - (4 * sd), mean + (4 * sd), 1000)
pdf = norm.pdf(func_x, loc = mean, scale = sd)

plt.figure(figsize = (8,6))
sns.kdeplot(resids, label = "Observed Redisual Distrubiton")
sns.lineplot(x = func_x, y = pdf, label = "Normal Distribution")
plt.axvline(0, color = "black", linestyle = "--")
plt.xlabel("Residuals")
plt.ylabel("Density")
plt.title("Linear regression model residual density vs normal")
plt.show()

# %%
ages = smmh["Q1"]
ax = sns.histplot(ages)
plt.title("Respondent age distribution")
plt.xlabel("Age")
ax.annotate('Figure 0: Histogram of Age Distribution', xy = (0, -.15), xycoords='axes fraction')
plt.show()

# %%
combined = pd.concat([
    pew_2020["AGE_AP20"],
    pew_2021["AGE_AP21"],
    pew_2022["AGE"],
    pew_2023["AGE"],
    pew_2024["AGE"]
])
combined = pd.to_numeric(combined, errors='coerce').dropna().astype(int)
sns.histplot(np.array(combined))
plt.show()

# %%
proportions = pew_2023.groupby("AGECAT").apply(lambda x: pd.Series({
    "Facebook": (x["SMUSE_a"] == "Yes, use this").mean(),
    "YouTube": (x["SMUSE_b"] == "Yes, use this").mean(),
    "Twitter": (x["SMUSE_c"] == "Yes, use this").mean(),
    "Instagram": (x["SMUSE_d"] == "Yes, use this").mean(),
    "Snapchat": (x["SMUSE_e"] == "Yes, use this").mean(),
    "WhatsApp": (x["SMUSE_f"] == "Yes, use this").mean(),
    "LinkedIn": (x["SMUSE_g"] == "Yes, use this").mean(),
    "Pinterest": (x["SMUSE_h"] == "Yes, use this").mean(),
    "TikTok": (x["SMUSE_i"] == "Yes, use this").mean(),
    "BeReal": (x["SMUSE_j"] == "Yes, use this").mean(),
    "Reddit": (x["SMUSE_k"] == "Yes, use this").mean(),
})
).reset_index()
# Out:
# C:\Users\harru\AppData\Local\Temp\ipykernel_28360\859944015.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   proportions = pew_2023.groupby("AGECAT").apply(lambda x: pd.Series({
# C:\Users\harru\AppData\Local\Temp\ipykernel_28360\859944015.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   proportions = pew_2023.groupby("AGECAT").apply(lambda x: pd.Series({

# %%
proportions = pd.melt(proportions, id_vars=["AGECAT"], var_name="Platform", value_name="Proportion")
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=proportions, x="Platform", y="Proportion", hue="AGECAT")
# Customize the plot
plt.title("Social Media Usage by Age Category in 2023", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Proportion")
plt.xlabel("Social Media Platform")
plt.legend(title="Age Category")
plt.tight_layout()
ax.annotate('Figure 2: Bar Plot of Social Media Platform Usage Proportions by Age Category in 2023', xy = (0, -.25), xycoords='axes fraction')
# Show the plot
plt.show()
